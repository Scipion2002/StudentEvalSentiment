# %%
import pandas as pd
import numpy as np
import spacy
import nltk

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("spacy:", spacy.__version__)
print("nltk:", nltk.__version__)

nlp = spacy.load("en_core_web_sm")
print("spaCy model loaded:", nlp.pipe_names)
# Out:
# pandas: 2.3.3
# numpy: 2.4.0
# spacy: 3.8.11
# nltk: 3.9.2
# spaCy model loaded: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
CrazyVariableName123 = "This is a test string."
print(CrazyVariableName123)
